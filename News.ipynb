# %% [markdown]
# <a href="https://colab.research.google.com/github/Vadimka29/JupiterNotebooks/blob/main/News.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Install Polygon Python Client https://github.com/polygon-io/client-python. This is a Python library that allows working with https://polygon.io REST API.

# %%
# !pip install -U polygon-api-client
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.4/143.4 kB 7.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 7.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.6
#     Uninstalling urllib3-2.0.6:
#       Successfully uninstalled urllib3-2.0.6
# ...

# %%
from polygon import RESTClient
polygonClient = RESTClient(api_key="***")
selectedTicker = 'TSLA'
articlesByTicker = polygonClient.list_ticker_news(ticker=selectedTicker)
for article in articlesByTicker:
  print(article)
# Out:
# TickerNews(amp_url=None, article_url='https://www.fool.com/investing/2023/10/14/sorry-cathie-wood-tesla-stock-9-trillion-market/', author='newsfeedback@fool.com (Jeremy Bowman)', description='Cathie Wood sees huge potential in autonomous vehicles, but there are better ways to get exposure to it than Tesla.', id='VmzAjb3hzoRXEmHD4HRYrwydw1NwdGjbGnDxuBj7hOY', image_url='https://g.foolcdn.com/editorial/images/750853/cruise-automation-origin-2020-mockup.jpg', keywords=['investing'], published_utc='2023-10-14T16:09:00Z', publisher=Publisher(favicon_url='https://s3.polygon.io/public/assets/news/favicons/themotleyfool.ico', homepage_url='https://www.fool.com/', logo_url='https://s3.polygon.io/public/assets/news/logos/themotleyfool.svg', name='The Motley Fool'), tickers=['TSLA', 'GOOGL', 'GM', 'GOOG', 'UBER'], title='Sorry, Cathie Wood. This, Not Tesla, Is the Stock to Own for the $9 Trillion Robotaxi Market.')
# ...
